# %%
from tensorflow.python.tools import inspect_checkpoint as chkp

# %%
chkp.print_tensors_in_checkpoint_file("/notebooks/selerio/pre_trained_weights/resnet_v2_50.ckpt", tensor_name='')
# Out:
# resnet_v2_50/postnorm/moving_variance (DT_FLOAT) [2048]
# resnet_v2_50/postnorm/moving_mean (DT_FLOAT) [2048]
# resnet_v2_50/postnorm/gamma/Momentum (DT_FLOAT) [2048]
# resnet_v2_50/postnorm/gamma/ExponentialMovingAverage (DT_FLOAT) [2048]
# resnet_v2_50/postnorm/beta/ExponentialMovingAverage (DT_FLOAT) [2048]
# resnet_v2_50/logits/biases/ExponentialMovingAverage (DT_FLOAT) [1001]
# resnet_v2_50/logits/biases (DT_FLOAT) [1001]
# resnet_v2_50/conv1/weights/Momentum (DT_FLOAT) [7,7,3,64]
# resnet_v2_50/conv1/weights (DT_FLOAT) [7,7,3,64]
# resnet_v2_50/conv1/biases/ExponentialMovingAverage (DT_FLOAT) [64]
# resnet_v2_50/block4/unit_3/bottleneck_v2/preact/moving_variance/ExponentialMovingAverage (DT_FLOAT) [2048]
# resnet_v2_50/block4/unit_3/bottleneck_v2/preact/moving_mean (DT_FLOAT) [2048]
# resnet_v2_50/block4/unit_3/bottleneck_v2/preact/gamma/Momentum (DT_FLOAT) [2048]
# resnet_v2_50/block4/unit_3/bottleneck_v2/preact/gamma (DT_FLOAT) [2048]
# ...
