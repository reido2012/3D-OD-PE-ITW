# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

import pascal3d
import numpy as np
import matplotlib.pyplot as plt
import scipy
# Out:
# /usr/local/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
import matplotlib.patches as patches
data_type = 'all'
dataset = pascal3d.dataset.Pascal3DDataset(data_type)
dataset.create_tfrecords(data_type)
# Out:
# Generating index for annotations...
# 138
# Done.
# <img src="data:image/png;base64,..." width="640">
# Shape
# (278, 500, 3)
# Original Shape - (278, 500, 3)
# Max Padding: 8
# Padded Image Shape: (294, 516, 3)
# Original Shape - (278, 500, 3)
# Max Padding: 0
# Padded Image Shape: (278, 500, 3)
# /usr/local/lib/python3.4/site-packages/ipykernel_launcher.py:11: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
#View Bounding Boxes 
# #print("Dataset Length: {}".format(len(dataset)))
# data_id = 'n02690373_16'
# fig = plt.figure()

# bboxs= [np.array([5,82,277,175]),np.array([298,116,483,182])]

# f_name = '/notebooks/selerio/datasets/pascal3d/PASCAL3D+_release1.1/Images/aeroplane_pascal/2008_000716.jpg'
# img = scipy.misc.imread(f_name)

# print("Shape")
# print(img.shape)

# fig.add_subplot(1,3, 1)
# plt.imshow(img)

# for counter, bbox in enumerate(bboxs):
#     resized = dataset._crop_object_from_img(img, bbox)

#     fig.add_subplot(1,3, counter+2)
#     plt.imshow(resized)

# plt.show()
# Out:
# ...
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Out:
# ...
#     100% |████████████████████████████████| 1.3MB 1.1MB/s eta 0:00:01
# ...
#   Found existing installation: pip 9.0.1
#     Uninstalling pip-9.0.1:
#       Successfully uninstalled pip-9.0.1
# ...
